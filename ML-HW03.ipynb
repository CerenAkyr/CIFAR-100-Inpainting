# %% [markdown]
# **<h5></h5>**
# **<h1><center>CS 464</center></h1>**
# **<h1><center>Introduction to Machine Learning</center></h1>**
# **<h1><center>Fall 2023</center></h1>**
# **<h1><center>Homework 3</center></h1>**
# <h4><center>Due: December 29, 2023 23:59 (GMT+3)</center></h4>

# %% [markdown]
# ## **CIFAR-100 Inpainting**

# %% [markdown]
# ### **Homework Description**

# %% [markdown]
# In this assignment, you are asked to design and train a convolutional neural network model for the image inpainting task. In short, inpainting is a process of filling in the missing parts of an image. You will be applying this task on the preprocessed CIFAR-100 dataset, which is created for this homework by processing the original [CIFAR-100](https://www.cs.toronto.edu/~kriz/cifar.html?ref=assemblyai.com) images. It contains RGB real-life images with the size of 28x28 pixel resolution. You can see a subset of the dataset below. The download link of the dataset is provided in the following parts.
#
# ![CIFAR-100 Samples](https://drive.google.com/uc?export=view&id=1drp11GJ3QnRivkYLR0nh9RVOi9lnIh8o)
#
# **Using PyTorch is mandatory** for this assignment. You are requested to **submit only a single *.ipynb file** in your submissions (no report needed). If you want to provide further explanations about your work, you can add Markdown cells for this purpose. From [this link](https://www.markdownguide.org/), you can get familiar with the Markdown syntax if you need. Upload your homework with the following filename convention: **\<BilkentID\>\_\<Name\>\_\<Surname\>.ipynb**
#
# Note that this assignment needs a CUDA-enabled GPU to be able to train the models in a reasonable time. If you do not have one, it is suggested to use the [Colab](https://colab.research.google.com/) environment.
#
# **Contact:** [Ahmet Burak Yıldırım](mailto:a.yildirim@bilkent.edu.tr)

# %% [markdown]
# ### **Importing the Libraries**

# %% [markdown]
# In the cell below,  some utilities that you can make use of in this assignment are imported. You can edit these imports considering your implementation as long as you use PyTorch.

# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, Dataset
import torchvision
from torchvision import transforms
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
import os

# %% [markdown]
# ### **Environment Check**

# %% [markdown]
# In the cell below, you can test whether hardware acceleration with GPU is enabled in your machine or not. If it is enabled, the printed device should be 'cuda'.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Current device:', device)

if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Current device: cuda
# GPU Name: Tesla T4
# Total GPU Memory: 14.7 GB

# %% [markdown]
# ### **Setting Library Seeds for Reproducibility**

# %% [markdown]
# **DO NOT CHANGE**<br>
# To make a fair evaluation, the seed values are set for random sampling methods in PyTorch, NumPy, and Python random library. Please do not change these values.

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything(464)

# %% [markdown]
# ### **Preparing the Dataset**

# %% [markdown]
# The CIFAR-100 dataset is downloadable from [this link](https://drive.google.com/file/d/1KiymtjUjuEJjUTO_qB9ifpLC_UvJEhoL/view?usp=share_link). If you are using Colab or a Linux machine, you can uncomment and run the below cell to download and extract the dataset automatically.

# %%
import gdown # Library to download files from Google Drive
# !gdown 1KiymtjUjuEJjUTO_qB9ifpLC_UvJEhoL # Google Drive ID of the zip file to be downloaded
# !unzip -oq cifar100.zip # Unzip the file downloaded. Options -o and -q overwrites the files if exists already and disables printing out the extracted files, respectively.
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KiymtjUjuEJjUTO_qB9ifpLC_UvJEhoL
# To: /content/cifar100.zip
# 100% 64.1M/64.1M [00:00<00:00, 102MB/s]

# %% [markdown]
# ### **Implementing a Custom Dataset [25 Points]**

# %% [markdown]
# In this part, you are requested to implement a custom PyTorch dataset class that reads CIFAR-100 images from a dataset split folder. There are two split folders called train and test in the dataset. The model class should take the root directory of a split in the \_\_init\_\_ function and read the images accordingly. Before returning the requested images, you should apply the following steps:
#
# * Apply bicubic interpolation using PIL to resize the images from (28,28) to (32,32) resolution.
# * Convert images to Tensor object
# * Normalize tensor values to scale them in the range of (-1,1)
#
# Note that reading images in the \_\_getitem\_\_ function makes the training process slow for this dataset because reading such small-sized images as a batch is slower than the forward pass process of a simple neural network. Therefore, it is suggested to read and store the images in an array in the \_\_init\_\_ function and return them in the \_\_getitem\_\_ function when they are requested by the DataLoader object.

# %%
class CifarDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.transform = transforms.Compose(
            [
                transforms.Resize((32, 32), Image.BICUBIC),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            ]
        )
        self.images = self.__set_up_images()

    def __set_up_images(self) -> list:
        images = []
        for directory_name in os.listdir(self.root_dir):
            image_dir = os.path.join(self.root_dir, directory_name)
            print(f"Reading images from {image_dir} ")
            subdirectory_imgs =  self.__read_subdirectory(image_dir)
            images.extend(subdirectory_imgs)
        return images


    def __read_subdirectory(self, subdirectory_path) -> list:
        images = []
        for file_name in os.listdir(subdirectory_path):
            img_path = os.path.join(subdirectory_path, file_name)
            with Image.open(img_path) as img:
                images.append(self.transform(img))
        return images


    def __len__(self):
        return len(self.images)

    def __getitem__(self, data_id):
        image = self.images[data_id]
        return image

# %% [markdown]
# Create a dataset and a data loader object for training and test splits. Set batch sizes to 64 and 512 for training and test data loaders, respectively. Enable shuffling in the training data loader and disable it in the test data loader.

# %%
train_root_dir = "cifar100/train"
test_root_dir = "cifar100/test"

train_dataset = CifarDataset(root_dir=train_root_dir)
test_dataset = CifarDataset(root_dir=test_root_dir)

batch_size_train = 64
batch_size_test = 512

train_dataloader = DataLoader(train_dataset, batch_size=batch_size_train, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size_test, shuffle=False)
# Out:
# Reading images from cifar100/train/beetle
# Reading images from cifar100/train/snail
# Reading images from cifar100/train/girl
# Reading images from cifar100/train/cattle
# Reading images from cifar100/train/leopard
# Reading images from cifar100/train/squirrel
# Reading images from cifar100/train/dolphin
# Reading images from cifar100/train/tank
# Reading images from cifar100/train/whale
# Reading images from cifar100/train/forest
# Reading images from cifar100/train/raccoon
# Reading images from cifar100/train/bicycle
# Reading images from cifar100/train/table
# Reading images from cifar100/train/elephant
# Reading images from cifar100/train/telephone
# Reading images from cifar100/train/crab
# Reading images from cifar100/train/television
# Reading images from cifar100/train/couch
# Reading images from cifar100/train/possum
# Reading images from cifar100/train/mountain
# Reading images from cifar100/train/castle
# Reading images from cifar100/train/aquarium_fish
# Reading images from cifar100/train/bridge
# Reading images from cifar100/train/pine_tree
# Reading images from cifar100/train/maple_tree
# Reading images from cifar100/train/worm
# Reading images from cifar100/train/plain
# Reading images from cifar100/train/shrew
# Reading images from cifar100/train/train
# Reading images from cifar100/train/streetcar
# Reading images from cifar100/train/pickup_truck
# Reading images from cifar100/train/butterfly
# Reading images from cifar100/train/camel
# Reading images from cifar100/train/boy
# Reading images from cifar100/train/willow_tree
# Reading images from cifar100/train/wardrobe
# Reading images from cifar100/train/can
# Reading images from cifar100/train/clock
# Reading images from cifar100/train/crocodile
# Reading images from cifar100/train/keyboard
# Reading images from cifar100/train/spider
# Reading images from cifar100/train/lamp
# Reading images from cifar100/train/mouse
# Reading images from cifar100/train/poppy
# Reading images from cifar100/train/caterpillar
# Reading images from cifar100/train/skunk
# Reading images from cifar100/train/kangaroo
# Reading images from cifar100/train/rocket
# Reading images from cifar100/train/house
# Reading images from cifar100/train/man
# Reading images from cifar100/train/rabbit
# Reading images from cifar100/train/motorcycle
# Reading images from cifar100/train/orange
# Reading images from cifar100/train/lobster
# Reading images from cifar100/train/shark
# Reading images from cifar100/train/bear
# Reading images from cifar100/train/woman
# Reading images from cifar100/train/oak_tree
# Reading images from cifar100/train/plate
# Reading images from cifar100/train/bus
# Reading images from cifar100/train/flatfish
# Reading images from cifar100/train/trout
# Reading images from cifar100/train/ray
# Reading images from cifar100/train/tulip
# Reading images from cifar100/train/cup
# Reading images from cifar100/train/bed
# Reading images from cifar100/train/pear
# Reading images from cifar100/train/cockroach
# Reading images from cifar100/train/hamster
# Reading images from cifar100/train/beaver
# Reading images from cifar100/train/road
# Reading images from cifar100/train/apple
# Reading images from cifar100/train/sunflower
# Reading images from cifar100/train/tiger
# Reading images from cifar100/train/tractor
# Reading images from cifar100/train/dinosaur
# Reading images from cifar100/train/wolf
# Reading images from cifar100/train/chimpanzee
# Reading images from cifar100/train/turtle
# Reading images from cifar100/train/skyscraper
# Reading images from cifar100/train/lawn_mower
# Reading images from cifar100/train/bowl
# Reading images from cifar100/train/lion
# Reading images from cifar100/train/mushroom
# Reading images from cifar100/train/cloud
# Reading images from cifar100/train/bottle
# Reading images from cifar100/train/porcupine
# Reading images from cifar100/train/sweet_pepper
# Reading images from cifar100/train/otter
# Reading images from cifar100/train/chair
# Reading images from cifar100/train/sea
# Reading images from cifar100/train/orchid
# Reading images from cifar100/train/seal
# Reading images from cifar100/train/snake
# Reading images from cifar100/train/palm_tree
# Reading images from cifar100/train/fox
# Reading images from cifar100/train/baby
# Reading images from cifar100/train/rose
# Reading images from cifar100/train/bee
# Reading images from cifar100/train/lizard
# Reading images from cifar100/test/beetle
# Reading images from cifar100/test/snail
# Reading images from cifar100/test/girl
# Reading images from cifar100/test/cattle
# Reading images from cifar100/test/leopard
# Reading images from cifar100/test/squirrel
# Reading images from cifar100/test/dolphin
# Reading images from cifar100/test/tank
# Reading images from cifar100/test/whale
# Reading images from cifar100/test/forest
# Reading images from cifar100/test/raccoon
# Reading images from cifar100/test/bicycle
# Reading images from cifar100/test/table
# Reading images from cifar100/test/elephant
# Reading images from cifar100/test/telephone
# Reading images from cifar100/test/crab
# Reading images from cifar100/test/television
# Reading images from cifar100/test/couch
# Reading images from cifar100/test/possum
# Reading images from cifar100/test/mountain
# Reading images from cifar100/test/castle
# Reading images from cifar100/test/aquarium_fish
# Reading images from cifar100/test/bridge
# Reading images from cifar100/test/pine_tree
# Reading images from cifar100/test/maple_tree
# Reading images from cifar100/test/worm
# Reading images from cifar100/test/plain
# Reading images from cifar100/test/shrew
# Reading images from cifar100/test/train
# Reading images from cifar100/test/streetcar
# Reading images from cifar100/test/pickup_truck
# Reading images from cifar100/test/butterfly
# Reading images from cifar100/test/camel
# Reading images from cifar100/test/boy
# Reading images from cifar100/test/willow_tree
# Reading images from cifar100/test/wardrobe
# Reading images from cifar100/test/can
# Reading images from cifar100/test/clock
# Reading images from cifar100/test/crocodile
# Reading images from cifar100/test/keyboard
# Reading images from cifar100/test/spider
# Reading images from cifar100/test/lamp
# Reading images from cifar100/test/mouse
# Reading images from cifar100/test/poppy
# Reading images from cifar100/test/caterpillar
# Reading images from cifar100/test/skunk
# Reading images from cifar100/test/kangaroo
# Reading images from cifar100/test/rocket
# Reading images from cifar100/test/house
# Reading images from cifar100/test/man
# Reading images from cifar100/test/rabbit
# Reading images from cifar100/test/motorcycle
# Reading images from cifar100/test/orange
# Reading images from cifar100/test/lobster
# Reading images from cifar100/test/shark
# Reading images from cifar100/test/bear
# Reading images from cifar100/test/woman
# Reading images from cifar100/test/oak_tree
# Reading images from cifar100/test/plate
# Reading images from cifar100/test/bus
# Reading images from cifar100/test/flatfish
# Reading images from cifar100/test/trout
# Reading images from cifar100/test/ray
# Reading images from cifar100/test/tulip
# Reading images from cifar100/test/cup
# Reading images from cifar100/test/bed
# Reading images from cifar100/test/pear
# Reading images from cifar100/test/cockroach
# Reading images from cifar100/test/hamster
# Reading images from cifar100/test/beaver
# Reading images from cifar100/test/road
# Reading images from cifar100/test/apple
# Reading images from cifar100/test/sunflower
# Reading images from cifar100/test/tiger
# Reading images from cifar100/test/tractor
# Reading images from cifar100/test/dinosaur
# Reading images from cifar100/test/wolf
# Reading images from cifar100/test/chimpanzee
# Reading images from cifar100/test/turtle
# Reading images from cifar100/test/skyscraper
# Reading images from cifar100/test/lawn_mower
# Reading images from cifar100/test/bowl
# Reading images from cifar100/test/lion
# Reading images from cifar100/test/mushroom
# Reading images from cifar100/test/cloud
# Reading images from cifar100/test/bottle
# Reading images from cifar100/test/porcupine
# Reading images from cifar100/test/sweet_pepper
# Reading images from cifar100/test/otter
# Reading images from cifar100/test/chair
# Reading images from cifar100/test/sea
# Reading images from cifar100/test/orchid
# Reading images from cifar100/test/seal
# Reading images from cifar100/test/snake
# Reading images from cifar100/test/palm_tree
# Reading images from cifar100/test/fox
# Reading images from cifar100/test/baby
# Reading images from cifar100/test/rose
# Reading images from cifar100/test/bee
# Reading images from cifar100/test/lizard

# %% [markdown]
# **Do not change** the below code. If your implementation is correct, you should be seeing a grid of CIFAR-100 images properly.

# %%
## Uncomment the cell when the dataloader is ready

images = next(iter(train_dataloader)) # Taking one batch from the dataloader
images = (images + 1) / 2
grid_img = torchvision.utils.make_grid(images[:20], nrow=10)
plt.axis('off')
plt.imshow(grid_img.permute(1, 2, 0))
plt.show()

# %% [markdown]
# ### **Constructing Convolutional Autoencoder Network [35 Points]**

# %% [markdown]
# Autoencoder networks learn how to compress and reconstruct input data. It consists of two networks called the encoder and the decoder. The encoder network compresses the input data, and the decoder network regenerates the data from its compressed version. In this part, you are requested to implement an autoencoder model using convolutional layers. The architecture of the convolutional autoencoder is shown in the below figure.

# %% [markdown]
# ![Convolutional Autoencoder Architecture](https://drive.google.com/uc?export=view&id=19RqHo2PatyoFl7om8OUxBRb1uYAVGmhF)
#
# The (in_channel, out_channel) pairs of the layers should be defined as follows:
#
# **Encoder:**
# - (3, 16)
# - (16, 32)
# - (32, 64)
#
# **Decoder:**
# - (64, 32)
# - (32, 16)
# - (16, 3)
#
# You are free to choose the kernel and padding sizes of the layers. In each layer, [2D batch normalization](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html) should be applied and the resulting values should be passed through a LeakyReLU layer with slope 0.2, which is the activation function. Since the image pixel value range is set to [-1,1] in the dataset, the outputs should be bounded so. Therefore, you should be using a Tanh activation function in the last layer instead of the normalization and LeakyReLU layers.
#
# In the encoder part of the network, use max pooling in each layer for decreasing the resolution by half. The stride size should be set to one for the convolution layers. In the decoder network, use [transposed convolution](https://pytorch.org/docs/stable/generated/torch.nn.ConvTranspose2d.html) (deconvolution) layers with stride two for increasing the resolution back.

# %%
class CifarAutoencoder(nn.Module):
    def __init__(self):
      super(CifarAutoencoder, self).__init__()

      kernel_size = 4 # best performance when kernel size = 4,
      # tried with different input & output paddings, find these as the best!

      self.encoder = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=kernel_size, stride=1, padding=2),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(16, 32, kernel_size=kernel_size, stride=1, padding=2),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(32, 64, kernel_size=kernel_size, stride=1, padding=2),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.MaxPool2d(2, 2)
        )

      self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=kernel_size, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(32, 16, kernel_size=kernel_size, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(16, 3, kernel_size=kernel_size, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

  #from torchsummary import summary

  #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  #model = CifarAutoencoder().to(device)
  #summary(model, (3, 32, 32))

# %% [markdown]
# ### **Implementing the Training Loop [15 Points]**

# %% [markdown]
# Define your training loop in this function. In the following parts, this function will be called to train the convolutional autoencoder. The input arguments are provided below. Apply the training progress and return a list of losses that are calculated on each epoch. You should sum the iteration losses up during an epoch and take the mean of them to calculate the running loss of that epoch.
#
# To be able to learn inpainting, you should mask the input images as follows:
#
# ![CIFAR Masking](https://drive.google.com/uc?export=view&id=1tlB0mNH4B5dKfokoe162qWgXgPDnOQi2)
#
# Simply, you should set the input tensor columns starting from 16 to 32 as -1 (black pixel). For the loss function, you should use the original image as the ground truth image so that the network learns how to fill the masked area of the input image and output the restored image. Before assigning the black pixels, do not forget to clone the original image to use it later in the loss function.

# %%
import torch.nn.functional as F

def train_model(model, train_dataloader, optimizer, loss_func, num_epochs):
    model.train()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    losses = []
    for epoch in range(num_epochs):
        running_loss = 0.0
        for i, data in enumerate(train_dataloader, 0):
            input_values = data.to(device)
            inputs_clone = input_values.clone()
            input_values[:, :, :, 16:32] = -1

            optimizer.zero_grad()
            outputs = model(input_values)


            loss = loss_func(outputs, inputs_clone)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        loss_on_epoch = running_loss / len(train_dataloader)
        losses.append(loss_on_epoch)
        print(f'On Epoch {epoch + 1}/{num_epochs} loss on epoch: {loss_on_epoch}')
    return losses

# %% [markdown]
# ### **Implementing the Evaluation Function [15 Points]**

# %% [markdown]
# Implement an evaluation function that returns the mean MSE calculated over the test dataset samples.

# %%
def MSE(input, target):
    nelement = input.data.nelement()

    target = target.to(input.device)
    return torch.sum((input - target) ** 2) /nelement

def evaluate_model(model, test_dataloader):
    model.eval()
    total_mse = 0.0
    total_samples = 0

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    with torch.no_grad():
        for _ , data in enumerate(test_dataloader, 0):
            inputs = data.clone().to(device)
            outputs = model(inputs)

            mse = MSE(outputs, data)
            total_mse += mse * inputs.size(0)
            total_samples += inputs.size(0)

    mean_mse = total_mse / total_samples
    return mean_mse

# %% [markdown]
# ### **Inpainting Visualization Function**

# %% [markdown]
# The below code will be used to visualize the outputs of the trained models later. **Do not change the codes in the cell**.

# %%
def visualize_inpainting(model, dataset):
    seed_everything(464)
    dataloader = DataLoader(dataset, batch_size=10, shuffle=True)
    images = next(iter(dataloader)) # Taking one batch from the dataloader
    images = images
    model.eval()
    with torch.no_grad():
      masked_images = images.clone()
      masked_images[:,:,:,16:] = -1
      inpainted_images = model(masked_images.cuda()).cpu()
    images = (images + 1) / 2
    masked_images = (masked_images + 1) / 2
    inpainted_images = (inpainted_images + 1) / 2
    images_concat = torch.cat((images, masked_images, inpainted_images), dim=2)
    grid_img = torchvision.utils.make_grid(images_concat, nrow=10)
    plt.axis('off')
    plt.imshow(grid_img.permute(1, 2, 0))
    plt.show()

# %% [markdown]
# ### **Training and Evaluating the Model [10 Points]**

# %% [markdown]
# Define your loss function as MSE, set learning rate to 2e-4, create Adam optimizer, and set number of epochs to 50. Later, call the train_model function that you implemented. Visualize the returned losses on a plot (loss vs. epoch). Lastly, call evaluate_model function that you implemented and print the mean square error that your model reached on the test dataset. Also, call the visualize_inpainting function to observe the final inpainting results on the test dataset.

# %%
seed_everything(464)

model = CifarAutoencoder()

loss_function = MSE
learn_rate = 2e-4

optimizer = optim.Adam(model.parameters(), lr=learn_rate)

epoch_count = 50

# Train the model
losses = train_model(model, train_dataloader, optimizer, loss_function, epoch_count)
# Out:
# On Epoch 1/50 loss on epoch: 0.11722184443260397
# On Epoch 2/50 loss on epoch: 0.08337870983364028
# On Epoch 3/50 loss on epoch: 0.07831463555964972
# On Epoch 4/50 loss on epoch: 0.07561611615197586
# On Epoch 5/50 loss on epoch: 0.07378412839358725
# On Epoch 6/50 loss on epoch: 0.07274834086160983
# On Epoch 7/50 loss on epoch: 0.07159664643847424
# On Epoch 8/50 loss on epoch: 0.07102372323441536
# On Epoch 9/50 loss on epoch: 0.07049290003145442
# On Epoch 10/50 loss on epoch: 0.06985843985739267
# On Epoch 11/50 loss on epoch: 0.0693011749535799
# On Epoch 12/50 loss on epoch: 0.06899428268527741
# On Epoch 13/50 loss on epoch: 0.06856818774910382
# On Epoch 14/50 loss on epoch: 0.06830352511437958
# On Epoch 15/50 loss on epoch: 0.06815010668409754
# On Epoch 16/50 loss on epoch: 0.06774342173943891
# On Epoch 17/50 loss on epoch: 0.06761564331038682
# On Epoch 18/50 loss on epoch: 0.06721589908651683
# On Epoch 19/50 loss on epoch: 0.0669847100858798
# On Epoch 20/50 loss on epoch: 0.06678609405179768
# On Epoch 21/50 loss on epoch: 0.06672545387159529
# On Epoch 22/50 loss on epoch: 0.06646105704252678
# On Epoch 23/50 loss on epoch: 0.06621138483304959
# On Epoch 24/50 loss on epoch: 0.06602877655240429
# On Epoch 25/50 loss on epoch: 0.06589275982011766
# On Epoch 26/50 loss on epoch: 0.06600438395653234
# On Epoch 27/50 loss on epoch: 0.06583458918344487
# On Epoch 28/50 loss on epoch: 0.06559472572525292
# On Epoch 29/50 loss on epoch: 0.0654626680142663
# On Epoch 30/50 loss on epoch: 0.06527746151037075
# On Epoch 31/50 loss on epoch: 0.06527701938701103
# On Epoch 32/50 loss on epoch: 0.06515685619448153
# On Epoch 33/50 loss on epoch: 0.06491904035020057
# On Epoch 34/50 loss on epoch: 0.06484650676626988
# On Epoch 35/50 loss on epoch: 0.06476853107628615
# On Epoch 36/50 loss on epoch: 0.06452621795865886
# On Epoch 37/50 loss on epoch: 0.06442487150278238
# On Epoch 38/50 loss on epoch: 0.06435604383954611
# On Epoch 39/50 loss on epoch: 0.06418659786224518
# On Epoch 40/50 loss on epoch: 0.0639635056466855
# On Epoch 41/50 loss on epoch: 0.0639363752435083
# On Epoch 42/50 loss on epoch: 0.06383150941251642
# On Epoch 43/50 loss on epoch: 0.06370894528944474
# On Epoch 44/50 loss on epoch: 0.06365962429424686
# On Epoch 45/50 loss on epoch: 0.06355831371453564
# On Epoch 46/50 loss on epoch: 0.06354132724349457
# On Epoch 47/50 loss on epoch: 0.06339493689729887
# On Epoch 48/50 loss on epoch: 0.06331326937317239
# On Epoch 49/50 loss on epoch: 0.06311704668090166
# On Epoch 50/50 loss on epoch: 0.06303763321465086

# %%
epochs = range(1, len(losses) + 1)
plt.plot(epochs, losses, 'b', label='Training lossws')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.xticks(range(1, len(losses), 5))
plt.legend()

# %%
# Evaluate the model
mean_mse = evaluate_model(model, test_dataloader)
print(f'Mean MSE: {mean_mse}')
# Out:
# Mean MSE: 0.05369080603122711

# %%
visualize_inpainting(model, test_dataset) ## Uncomment when the model is trained
